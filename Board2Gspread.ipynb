# %% [markdown]
# ### イベント基礎データ取得

# %%
import requests
from typing import Any, Dict, List, Optional, Tuple
from datetime import datetime, timedelta, timezone, time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

BASE_URL = "https://api.sekai.best"
REGION = "jp"
EVENTS_JSON_URL = (
    "https://raw.githubusercontent.com/Sekai-World/sekai-master-db-diff/"
    "main/events.json"
)
JST = timezone(timedelta(hours=9))

# %% [markdown]
# #### イベントデータ一覧取得

# %%
def fetch_event_list():
    resp = requests.get(EVENTS_JSON_URL)
    resp.raise_for_status()
    data = resp.json()
    if not isinstance(data, list):
        raise ValueError("events.json の中身がリストではありません。")
    return data

# %%
def list_event_names():
    events = fetch_event_list()
    event_names = [e["name"] for e in events if isinstance(e, dict) and "name" in e]
    print("\n".join(event_names))

# %%
def get_event_info_by_name(event_name):
    events = fetch_event_list()
    for evt in events:
        if not isinstance(evt, dict):
            continue
        if evt.get("name") == event_name:
            return evt
    raise ValueError(f"イベント名【{event_name}】が見つかりませんでした。")

# %%
def filter_event_info(evt):
    return evt.get("id"), datetime.fromtimestamp(evt.get("startAt") / 1000, tz=JST), datetime.fromtimestamp(evt.get("aggregateAt") / 1000, tz=JST)

# %% [markdown]
# #### イベント名から ID と開催期間を抽出

# %%
filter_event_info(get_event_info_by_name("いつか花咲くステージへ"))
# Out:
# (130,
#  datetime.datetime(2024, 5, 9, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))),
#  datetime.datetime(2024, 5, 21, 19, 59, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))))

# %% [markdown]
# ---
# ### まずは通常イベントのランキング取得

# %%
def get_event_time(event_id):
    url = f"{BASE_URL}/event/{event_id}/rankings/time"
    params = {
        "region": REGION
    }
    try:
        resp = requests.get(url, params=params, timeout=10)
        print("Status:", resp.status_code)
        print("URL:", resp.url)
        resp.raise_for_status()
        payload = resp.json()
        data = payload.get("data", [])
        return data if isinstance(data, list) else []
    except Exception as e:
        print("Error:", e)
        return []

# %%
event_id, _, _ = filter_event_info(get_event_info_by_name("いつか花咲くステージへ"))
times = get_event_time(event_id)
# Out:
# Status: 200
# URL: https://api.sekai.best/event/130/rankings/time?region=jp

# %%
def get_event_rankings(event_id, ts):
    url = f"{BASE_URL}/event/{event_id}/rankings"
    params = {"timestamp": ts, "region": REGION}
    try:
        resp = requests.get(url, params=params, timeout=100)
        print("Status:", resp.status_code)
        print("URL:", resp.url)
        resp.raise_for_status()
        payload = resp.json()
        data = payload.get("data")
        return data.get("eventRankings")
    except Exception as e:
        print("Error:", e)
        return []

# %%
get_event_rankings(event_id, times[0])
# Out:
# Status: 200
# URL: https://api.sekai.best/event/130/rankings?timestamp=2024-05-10T08%3A39%3A00.549Z&region=jp
# [{'id': 30237160,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 1,
#   'score': 54151652,
#   'userId': '8343521107030030',
#   'userName': '愛莉ちゃんカワイイな',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'みずえなしずあい',
#    'userId': '8343521107030030',
#    'twitterId': 'mamemamemame_p',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072002,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1072002,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 3411,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237161,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 2,
#   'score': 52759431,
#   'userId': '8095312367759366',
#   'userName': 'むっ♡',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'むっむっむっむっむっむっむっむっむっむっむっむっむっむっむっ',
#    'userId': '8095312367759366',
#    'twitterId': ' ',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1122,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237162,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 3,
#   'score': 52146092,
#   'userId': '8258873404719115',
#   'userName': 'ペンギン',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '8258873404719115',
#    'twitterId': 'BBC',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2710,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1050702,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1050703,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 30237163,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 4,
#   'score': 50766265,
#   'userId': '5504355306815497',
#   'userName': '松坂さとう♡♡',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ただいま、ハッピーシュガーライフ',
#    'userId': '5504355306815497',
#    'twitterId': 'kanaeitas0',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 55,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 79,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237164,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 5,
#   'score': 50349947,
#   'userId': '5950589112995846',
#   'userName': 'マリアＳレオンブルク',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'おいでなさぁい',
#    'userId': '5950589112995846',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': []},
#  {'id': 30237165,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 6,
#   'score': 50141513,
#   'userId': '40436672663736334',
#   'userName': 'わらってほしくて',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'さてと',
#    'userId': '40436672663736334',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 65,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 127,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2164,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237166,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 7,
#   'score': 49850810,
#   'userId': '194747444055318540',
#   'userName': 'ミルダ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '2022.03.07スタート！！',
#    'userId': '194747444055318540',
#    'twitterId': 'Mildaness_S0912',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1070802,
#     'honorLevel': 6,
#     'bondsHonorWordId': 1070803,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 3,
#     'honorId': 2311,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237167,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 8,
#   'score': 48570815,
#   'userId': '5866563153145861',
#   'userName': 'スコティッシュ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '猫耳ハートは難しい',
#    'userId': '5866563153145861',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1071401,
#     'honorLevel': 5,
#     'bondsHonorWordId': 1071401,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 116,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 535,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237168,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 9,
#   'score': 48314640,
#   'userId': '245137073019084804',
#   'userName': 'まいなん！？',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'あかざ推し♡',
#    'userId': '245137073019084804',
#    'twitterId': 'maidayo_zzzzz',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3025,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 147,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1147,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237169,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 10,
#   'score': 48005180,
#   'userId': '175586094221455362',
#   'userName': 'やるじゃない桃井愛莉',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛遥推しの配信者です！ようつべにて配信中',
#    'userId': '175586094221455362',
#    'twitterId': 'bloodkiller84',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2714,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3027,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237170,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 11,
#   'score': 47668776,
#   'userId': '5237215198707727',
#   'userName': 'きら☆',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'かわいいは正義！',
#    'userId': '5237215198707727',
#    'twitterId': 'ria_kiramizu',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3025,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 79,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237171,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 12,
#   'score': 47375634,
#   'userId': '14486204422983688',
#   'userName': 'ゆたぐ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '14486204422983688',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 492,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 30,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237172,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 13,
#   'score': 46940938,
#   'userId': '5140795992735744',
#   'userName': 'あさむー♡｡*',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ビバハピ周回いっくよ〜！',
#    'userId': '5140795992735744',
#    'twitterId': 'asam_1206',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 2713,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 19,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237173,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 14,
#   'score': 46162203,
#   'userId': '44406495278120967',
#   'userName': 'ほたる',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'WL愛莉バナー100位目指して頑張ります！！',
#    'userId': '44406495278120967',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072202,
#     'honorLevel': 6,
#     'bondsHonorWordId': 1072201,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'},
#    {'seq': 2,
#     'honorId': 2,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 74,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237174,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 15,
#   'score': 45559252,
#   'userId': '5308680271167502',
#   'userName': 'NiGHTFALL教',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'その心に降る景色と\xa0同じものを抱きしめながら生きたい気がした',
#    'userId': '5308680271167502',
#    'twitterId': 'nbk_prsk',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 2,
#     'honorId': 874,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2957,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237175,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 16,
#   'score': 45454650,
#   'userId': '5249477724610574',
#   'userName': 'お知らせが読める豆腐',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'アイリスギアイリシス',
#    'userId': '5249477724610574',
#    'twitterId': 'bhsta58199',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072502,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1072503,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237176,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 17,
#   'score': 45438432,
#   'userId': '8428455415369732',
#   'userName': 'いいトスよこせよ！',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '8428455415369732',
#    'twitterId': 'rio_usapi___',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237177,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 18,
#   'score': 45224771,
#   'userId': '96082934628372484',
#   'userName': '暁人くん結婚して！！',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '一旦せめよんﾏ??',
#    'userId': '96082934628372484',
#    'twitterId': 'prsktagnanato',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237178,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 19,
#   'score': 45118701,
#   'userId': '7078025925906447',
#   'userName': '命への執着の究極形態',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '7078025925906447',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': []},
#  {'id': 30237179,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 20,
#   'score': 45045700,
#   'userId': '5201032506245124',
#   'userName': '東方百雀伝',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '完全南極Dreamer',
#    'userId': '5201032506245124',
#    'twitterId': 'MOJUMP',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 2634,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1050602,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1050603,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 1070802,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1070803,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 30237180,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 21,
#   'score': 44810873,
#   'userId': '269724741388005376',
#   'userName': 'ｶﾞｿﾘﾝｶｰみみみ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '269724741388005376',
#    'twitterId': 'car_mimimi',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 128,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1070802,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1070803,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 30237181,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 22,
#   'score': 44419550,
#   'userId': '275206611190853640',
#   'userName': '思い出なんかいらん',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '275206611190853640',
#    'twitterId': 'setu_prsk',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237182,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 23,
#   'score': 44269305,
#   'userId': '6930355169308673',
#   'userName': 'ピンクちゃん',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '込み上げる熱い想い流れてしまわぬように',
#    'userId': '6930355169308673',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1071402,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1071401,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3998,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237183,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 24,
#   'score': 43782985,
#   'userId': '10675019671805956',
#   'userName': '桃井さつき',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ラブリーフェアリー！',
#    'userId': '10675019671805956',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 787,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237184,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 25,
#   'score': 43519166,
#   'userId': '242498278310477835',
#   'userName': '団子大先生',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'お花咲いたよ',
#    'userId': '242498278310477835',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072001,
#     'honorLevel': 5,
#     'bondsHonorWordId': 1072002,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 79,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237185,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 26,
#   'score': 42816520,
#   'userId': '5205915209191430',
#   'userName': 'つぐみかん♡*゜',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '❀❁',
#    'userId': '5205915209191430',
#    'twitterId': 'o3o_293',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1970,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 972,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237186,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 27,
#   'score': 42469035,
#   'userId': '42300771357908994',
#   'userName': '目指せ炊き忘れ0回！',
#   'userCard': {'level': 60,
#    'cardId': 429,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '42300771357908994',
#    'twitterId': 'norii_p_q',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072002,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1072002,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 3411,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3030,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237187,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 28,
#   'score': 42359725,
#   'userId': '383191131972980744',
#   'userName': 'ら',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '383191131972980744',
#    'twitterId': 'O3l9_Airi',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 2,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3829,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237188,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 29,
#   'score': 42230829,
#   'userId': '305585330375680003',
#   'userName': 'ゆの',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '2023.1.7にはじめました。',
#    'userId': '305585330375680003',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 116,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2718,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2891,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237189,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 30,
#   'score': 42134679,
#   'userId': '8219059984592896',
#   'userName': '日耀@150/665',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '\xa0',
#    'userId': '8219059984592896',
#    'twitterId': 'qirenchang',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2154,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237190,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 31,
#   'score': 41855801,
#   'userId': '5670384947429388',
#   'userName': 'まーる',
#   'userCard': {'level': 60,
#    'cardId': 840,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛莉チャプター中は招待等行けないですごめんなさい',
#    'userId': '5670384947429388',
#    'twitterId': 'MARE_hszk',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 2634,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 337,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237191,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 32,
#   'score': 41307243,
#   'userId': '163281841554284546',
#   'userName': '醋漁@愛莉マニア',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'qq3051647356\xa0愛莉推し\xa0今仏蘭西居る',
#    'userId': '163281841554284546',
#    'twitterId': 'sumaru10ningbo',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3033,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1356,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237192,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 33,
#   'score': 40904052,
#   'userId': '204874730662350857',
#   'userName': '陰陽の開祖',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'はい',
#    'userId': '204874730662350857',
#    'twitterId': 'shadowverse_jp',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 142,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237193,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 34,
#   'score': 40828306,
#   'userId': '5157068944814081',
#   'userName': 'ななみ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'H@PPY\xa0EVERYDAY!',
#    'userId': '5157068944814081',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1122,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237194,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 35,
#   'score': 40539321,
#   'userId': '5632391829917697',
#   'userName': '冴えない愛莉の育て方',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '5632391829917697',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1071902,
#     'honorLevel': 7,
#     'bondsHonorWordId': 1071903,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 75,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237195,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 36,
#   'score': 40164796,
#   'userId': '11054791828836359',
#   'userName': 'れい吉さん',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'モアモアしてきた。',
#    'userId': '11054791828836359',
#    'twitterId': 'raykiti46',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1060702,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1060701,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 1302,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 27,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237196,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 37,
#   'score': 40088061,
#   'userId': '81004993335050242',
#   'userName': '二時？\u3000夜中の！？',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'からみ',
#    'userId': '81004993335050242',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2712,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237197,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 38,
#   'score': 39076445,
#   'userId': '194230132281470979',
#   'userName': 'メリーさん@風邪',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ワールドリンク全力投球！！風邪治れ治れ治れ！！',
#    'userId': '194230132281470979',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 128,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2720,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237198,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 39,
#   'score': 38988423,
#   'userId': '126256992944562177',
#   'userName': 'ごましろ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '石が消えていく…',
#    'userId': '126256992944562177',
#    'twitterId': 'tirol33cc',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1977,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237199,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 40,
#   'score': 38961762,
#   'userId': '38972779747631106',
#   'userName': 'クロロ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '全身全霊モアモアジャンプ',
#    'userId': '38972779747631106',
#    'twitterId': 'krr_0966',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2721,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1983,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237200,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 41,
#   'score': 38932969,
#   'userId': '344097333846388741',
#   'userName': 'シウ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '344097333846388741',
#    'twitterId': 'tierra57051628',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1071102,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1071102,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3031,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237201,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 42,
#   'score': 38555188,
#   'userId': '5143797940097034',
#   'userName': '琥珀',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛莉最高',
#    'userId': '5143797940097034',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1071902,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1071901,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 3033,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237202,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 43,
#   'score': 38391058,
#   'userId': '18953666266714123',
#   'userName': 'ハッピーえへへデイ♡',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛莉チャプターにえへへスタを添えて',
#    'userId': '18953666266714123',
#    'twitterId': '_oh87',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3030,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 83,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237203,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 44,
#   'score': 38356445,
#   'userId': '9735816595656715',
#   'userName': 'くめる',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '宮女三年生組推し',
#    'userId': '9735816595656715',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 71,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2714,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237204,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 45,
#   'score': 38113241,
#   'userId': '8381290555027456',
#   'userName': '* 彩菓 *',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'みにょ♡',
#    'userId': '8381290555027456',
#    'twitterId': '和喫茶「猫まみれ」',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 19,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1050702,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1050703,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 30237205,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 46,
#   'score': 37811741,
#   'userId': '292298204515356679',
#   'userName': 'ミズキ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '二本指で\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000マスター31以下全FC！！！！',
#    'userId': '292298204515356679',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1072202,
#     'honorLevel': 7,
#     'bondsHonorWordId': 1072203,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'},
#    {'seq': 3,
#     'honorId': 3013,
#     'honorLevel': 41,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237206,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 47,
#   'score': 37749401,
#   'userId': '290238681758941189',
#   'userName': 'ハッピー反復横跳び！',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '周回招待嬉しいです！',
#    'userId': '290238681758941189',
#    'twitterId': 'Om_suB_56rn',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2719,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3035,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237207,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 48,
#   'score': 37564497,
#   'userId': '172055546081873924',
#   'userName': ' ',
#   'userCard': {'level': 60,
#    'cardId': 617,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '172055546081873924',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 127,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237208,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 49,
#   'score': 37382498,
#   'userId': '47972823473405962',
#   'userName': 'うっちー',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'モモWL頑張るぞ！',
#    'userId': '47972823473405962',
#    'twitterId': 'UY_uchi1710',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3014,
#     'honorLevel': 40,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2516,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237209,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 50,
#   'score': 37233833,
#   'userId': '343362185375293448',
#   'userName': 'suna',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '343362185375293448',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1070802,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1070801,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 1050601,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1050601,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 30237210,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 51,
#   'score': 37136895,
#   'userId': '5263552747220999',
#   'userName': '和菓子屋 桃井',
#   'userCard': {'level': 60,
#    'cardId': 547,
#    'masterRank': 0,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'あいり先輩とキズナを育むぞー！おー！',
#    'userId': '5263552747220999',
#    'twitterId': 'airi_oshitoufu',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1050702,
#     'honorLevel': 7,
#     'bondsHonorWordId': 1050703,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1979,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237211,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 52,
#   'score': 36929679,
#   'userId': '38509334782644225',
#   'userName': 'えびびん',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'てぇてぇ',
#    'userId': '38509334782644225',
#    'twitterId': 'Ebibin_prsk',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2715,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237212,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 53,
#   'score': 36871075,
#   'userId': '155239693092683778',
#   'userName': '！',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '155239693092683778',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237213,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 54,
#   'score': 36739445,
#   'userId': '8565252363390991',
#   'userName': 'かな♡',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
# ...
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 50000,
#   'score': 271520,
#   'userId': '12614677641064449',
#   'userName': 'テイルス',
#   'userCard': {'level': 60,
#    'cardId': 556,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '12614677641064449',
#    'twitterId': 'Tails9905',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 66,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 74,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 78,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237264,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 40000,
#   'score': 309732,
#   'userId': '237070898016337931',
#   'userName': '夏の瓜',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 2,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'しがない瓜です。',
#    'userId': '237070898016337931',
#    'twitterId': 'MiaMia7280',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1202302,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1202301,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'},
#    {'seq': 2,
#     'honorId': 3618,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 78,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237265,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 30000,
#   'score': 361158,
#   'userId': '5227773962489862',
#   'userName': 'ねことらっぷ',
#   'userCard': {'level': 60,
#    'cardId': 803,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'キツネコミクさんとツインテ奏の実装まだ？',
#    'userId': '5227773962489862',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 82,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 65,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 25,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237266,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 20000,
#   'score': 446103,
#   'userId': '5825365675126789',
#   'userName': 'M&E',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '8/27-4/30\xa0\xa0\xa0\xa0瑞希絵名推し',
#    'userId': '5825365675126789',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1192002,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1192003,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 79,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 74,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237267,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 10000,
#   'score': 667392,
#   'userId': '16053507547418639',
#   'userName': 'リアナ',
#   'userCard': {'level': 60,
#    'cardId': 392,
#    'masterRank': 1,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '機種変してからタップの反応が悪い…どうしよう',
#    'userId': '16053507547418639',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 62,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 112,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 729,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237268,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 5000,
#   'score': 1094595,
#   'userId': '119737270257737738',
#   'userName': 'ユウ',
#   'userCard': {'level': 50,
#    'cardId': 841,
#    'masterRank': 0,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'not_doing'},
#   'userProfile': {'word': '',
#    'userId': '119737270257737738',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 42,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3703,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2158,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237269,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 4000,
#   'score': 1301445,
#   'userId': '375932927685574667',
#   'userName': 'もやし二袋',
#   'userCard': {'level': 50,
#    'cardId': 132,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'よろしくお願いします！',
#    'userId': '375932927685574667',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3583,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 66,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1172002,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1172002,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 30237270,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 3000,
#   'score': 1669777,
#   'userId': '5166468774506498',
#   'userName': 'まゆみえ',
#   'userCard': {'level': 60,
#    'cardId': 921,
#    'masterRank': 3,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'みのりんりんっ！',
#    'userId': '5166468774506498',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1050602,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1050602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 18,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 22,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237271,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 2500,
#   'score': 1959215,
#   'userId': '68310331528650753',
#   'userName': '♯夜空',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '順位落ちるの鬼はやい',
#    'userId': '68310331528650753',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 58,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 42,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 26,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237272,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 2000,
#   'score': 2416534,
#   'userId': '240799490378768384',
#   'userName': 'しゅしゅしゅ',
#   'userCard': {'level': 60,
#    'cardId': 368,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ふう',
#    'userId': '240799490378768384',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1060701,
#     'honorLevel': 5,
#     'bondsHonorWordId': 1060702,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 2724,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237273,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 1500,
#   'score': 3307025,
#   'userId': '73608654338662414',
#   'userName': 'いちみる',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'イベらん',
#    'userId': '73608654338662414',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1070802,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2369,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237274,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 1000,
#   'score': 5209360,
#   'userId': '70444713517629452',
#   'userName': '♥',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '称号4つ付けさせて！！',
#    'userId': '70444713517629452',
#    'twitterId': 'metoo_0517',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1222302,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1222301,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 1050602,
#     'honorLevel': 3,
#     'bondsHonorWordId': 1050602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 1070802,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 30237275,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 500,
#   'score': 8284103,
#   'userId': '155635838042374144',
#   'userName': 'さん',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'へぇ。真田、タンポポ知ってるんだ',
#    'userId': '155635838042374144',
#    'twitterId': 'hian3g',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237276,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 400,
#   'score': 9602820,
#   'userId': '109853722259132419',
#   'userName': 'ひかる',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ダショ贔屓の全キャラ推し',
#    'userId': '109853722259132419',
#    'twitterId': 'Hikaru_DC',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1141502,
#     'honorLevel': 6,
#     'bondsHonorWordId': 1141503,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 4021,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3967,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237277,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 300,
#   'score': 11974597,
#   'userId': '5946489465610245',
#   'userName': '暁',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '彰人と愛莉の八重歯',
#    'userId': '5946489465610245',
#    'twitterId': ' ',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 43,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 47,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 30237278,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 200,
#   'score': 16535941,
#   'userId': '254476858535956487',
#   'userName': 'しゅん_hr',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'キズナ上げはじめました',
#    'userId': '254476858535956487',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 78,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1202402,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1202402,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'},
#    {'seq': 3,
#     'honorId': 1072002,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1072001,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 30237279,
#   'eventId': 130,
#   'timestamp': '2024-05-10T08:39:00.549Z',
#   'rank': 100,
#   'score': 30187160,
#   'userId': '6722843379507203',
#   'userName': '音喜多クレノ＠モナカ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛莉ちゃんパパの作るお弁当の蓋になりたい',
#    'userId': '6722843379507203',
#    'twitterId': 'otokita_creno',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1070802,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 30,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]}]

# %% [markdown]
# ---
# ### WL に対応させるため event_id とチャプター番号から character_id を抽出

# %%
WORLD_BLOOM_JSON_URL = (
    "https://raw.githubusercontent.com/Sekai-World/sekai-master-db-diff/"
    "main/worldBlooms.json"
)
def fetch_world_bloom():
    resp = requests.get(WORLD_BLOOM_JSON_URL)
    resp.raise_for_status()
    data = resp.json()
    if not isinstance(data, list):
        raise ValueError("events.json の中身がリストではありません。")
    return data

# %%
def get_game_character_id(event_id, chapter_no):
    items = fetch_world_bloom()
    return next(
        (o.get("gameCharacterId")
         for o in items
         if o.get("eventId") == event_id and o.get("chapterNo") == chapter_no),
        None
    )

# %%
chara_id = get_game_character_id(130, 1)

# %% [markdown]
# #### WL chapter 単位のランキング取得

# %%
def get_chapter_time(event_id, chara_id):
    url = f"{BASE_URL}/event/{event_id}/chapter_rankings/time"
    params = {"charaId": chara_id, "region": REGION}
    try:
        resp = requests.get(url, params=params, timeout=10)
        print("Status:", resp.status_code)
        print("URL:", resp.url)
        resp.raise_for_status()
        payload = resp.json()
        data = payload.get("data", [])
        return data if isinstance(data, list) else []
    except Exception as e:
        print("Error:", e)
        return []

# %%
event_id, _, _ = filter_event_info(get_event_info_by_name("いつか花咲くステージへ"))
times = get_chapter_time(event_id, chara_id)
# Out:
# Status: 200
# URL: https://api.sekai.best/event/130/chapter_rankings/time?charaId=7&region=jp

# %%
def get_chapter_rankings(event_id, chara_id, ts):
    url = f"{BASE_URL}/event/{event_id}/chapter_rankings"
    params = {"charaId": chara_id, "timestamp": ts, "region": REGION}
    try:
        resp = requests.get(url, params=params, timeout=100)
        print("Status:", resp.status_code)
        print("URL:", resp.url)
        resp.raise_for_status()
        payload = resp.json()
        data = payload.get("data")
        return data.get("eventRankings")
    except Exception as e:
        print("Error:", e)
        return []

# %%
rankings = get_chapter_rankings(event_id, chara_id, times[0])
# Out:
# Status: 200
# URL: https://api.sekai.best/event/130/chapter_rankings?charaId=7&timestamp=2024-05-09T11%3A03%3A00.274Z&region=jp

# %%
rankings
# Out:
# [{'id': 132120,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 1,
#   'score': 88095,
#   'userId': '12150586078896140',
#   'userName': '☀ぱっぱらぱむらんど',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ぱっぱらぱむらんど！！！！',
#    'userId': '12150586078896140',
#    'twitterId': 'pamuun_prsk',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 19,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 23,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132121,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 2,
#   'score': 86765,
#   'userId': '8343521107030030',
#   'userName': '愛莉ちゃんカワイイな',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'みずえなしずあい',
#    'userId': '8343521107030030',
#    'twitterId': 'mamemamemame_p',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072002,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1072002,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 3411,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132122,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 3,
#   'score': 86345,
#   'userId': '8095312367759366',
#   'userName': 'むっ♡',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'むっむっむっむっむっむっむっむっむっむっむっむっむっむっむっ',
#    'userId': '8095312367759366',
#    'twitterId': ' ',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1122,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132123,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 4,
#   'score': 86100,
#   'userId': '5164257415458821',
#   'userName': 'あこり♡',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ハッピー反復横跳びで空をとぶ',
#    'userId': '5164257415458821',
#    'twitterId': 'nekomimi_whale',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1060701,
#     'honorLevel': 3,
#     'bondsHonorWordId': 1060701,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 1072202,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1072201,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse_unit_virtual_singer'},
#    {'seq': 3,
#     'honorId': 1071902,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1071901,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 132124,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 5,
#   'score': 85960,
#   'userId': '5237215198707727',
#   'userName': 'きら☆',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'かわいいは正義！',
#    'userId': '5237215198707727',
#    'twitterId': 'ria_kiramizu',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3025,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 79,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132125,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 6,
#   'score': 85120,
#   'userId': '5201032506245124',
#   'userName': '東方百雀伝',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '完全南極Dreamer',
#    'userId': '5201032506245124',
#    'twitterId': 'MOJUMP',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 2634,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1050602,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1050603,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 1070802,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1070803,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 132126,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 7,
#   'score': 84875,
#   'userId': '5249477724610574',
#   'userName': 'お知らせが読める豆腐',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'アイリスギアイリシス',
#    'userId': '5249477724610574',
#    'twitterId': 'bhsta58199',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072502,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1072503,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132127,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 8,
#   'score': 83790,
#   'userId': '8428455415369732',
#   'userName': 'いいトスよこせよ！',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '8428455415369732',
#    'twitterId': 'rio_usapi___',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132128,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 9,
#   'score': 83370,
#   'userId': '5137046532431873',
#   'userName': 'はなこ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '5137046532431873',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 329,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 973,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1973,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132129,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 10,
#   'score': 83265,
#   'userId': '5157068944814081',
#   'userName': 'ななみ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'H@PPY\xa0EVERYDAY!',
#    'userId': '5157068944814081',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 2,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 67,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132130,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 11,
#   'score': 83125,
#   'userId': '40436672663736334',
#   'userName': 'わらってほしくて',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'さてと',
#    'userId': '40436672663736334',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 65,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 127,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2164,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132131,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 12,
#   'score': 82985,
#   'userId': '7078025925906447',
#   'userName': '命への執着の究極形態',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '7078025925906447',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': []},
#  {'id': 132132,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 13,
#   'score': 82670,
#   'userId': '13742896516046862',
#   'userName': 'るーろん',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '気ままにやってます',
#    'userId': '13742896516046862',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132133,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 14,
#   'score': 82005,
#   'userId': '18953666266714123',
#   'userName': 'ハッピーえへへデイ♡',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛莉チャプターにえへへスタを添えて',
#    'userId': '18953666266714123',
#    'twitterId': '_oh87',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3030,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 83,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132134,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 15,
#   'score': 80885,
#   'userId': '110369629016207367',
#   'userName': '夢見る空はいつだって',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '快晴選んでくれる心優しい人に、幸せが降りますように♡',
#    'userId': '110369629016207367',
#    'twitterId': 'iano_account319',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2154,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1122,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132135,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 16,
#   'score': 79730,
#   'userId': '245137073019084804',
#   'userName': 'まいなん！？',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'あかざ推し♡',
#    'userId': '245137073019084804',
#    'twitterId': 'maidayo_zzzzz',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3025,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 147,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1147,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132136,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 17,
#   'score': 79520,
#   'userId': '5232840149127168',
#   'userName': 'ありす☆彡',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'リン愛莉推し♡',
#    'userId': '5232840149127168',
#    'twitterId': 'alice_prsk_rin',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 2713,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 116,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132137,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 18,
#   'score': 79275,
#   'userId': '158933536032071695',
#   'userName': 'カッパのカールくん',
#   'userCard': {'level': 60,
#    'cardId': 547,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '158933536032071695',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 534,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3239,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132138,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 19,
#   'score': 77980,
#   'userId': '5243971895500811',
#   'userName': 'はく',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '愛莉推し',
#    'userId': '5243971895500811',
#    'twitterId': 'Xiemaomi',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1425,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 22,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132139,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 20,
#   'score': 77910,
#   'userId': '42300771357908994',
#   'userName': '目指せ炊き忘れ0回！',
#   'userCard': {'level': 60,
#    'cardId': 429,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '42300771357908994',
#    'twitterId': 'norii_p_q',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1072002,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1072002,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 3411,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3030,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132140,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 21,
#   'score': 75810,
#   'userId': '5170074684485641',
#   'userName': 'も',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '@mpl_052(鍵)桃雫チャプ走ります。みの遥支援招待◎',
#    'userId': '5170074684485641',
#    'twitterId': 'MCRN_tabetai',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1070802,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1070803,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 18,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 22,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132141,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 22,
#   'score': 75775,
#   'userId': '330635809937944591',
#   'userName': 'Maze',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '桐谷遥すき',
#    'userId': '330635809937944591',
#    'twitterId': 'Maze_prsk',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 23,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2767,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2634,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132142,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 23,
#   'score': 75495,
#   'userId': '22022730698493952',
#   'userName': 'CUL',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ワールドリンクに向けて',
#    'userId': '22022730698493952',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 981,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1982,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132143,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 24,
#   'score': 75320,
#   'userId': '82150925728423951',
#   'userName': 'ド級のリトライ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ドリトライだ',
#    'userId': '82150925728423951',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132144,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 25,
#   'score': 74515,
#   'userId': '252040901962158087',
#   'userName': '#FFAACC',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '252040901962158087',
#    'twitterId': 't5em0',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132145,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 26,
#   'score': 73920,
#   'userId': '431010751475716103',
#   'userName': '誇り高き戦士',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'いろはにほへと♩',
#    'userId': '431010751475716103',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3224,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 26,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1070801,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1070801,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 132146,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 27,
#   'score': 71890,
#   'userId': '5258713472806921',
#   'userName': '松風',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'イベランって大変やな',
#    'userId': '5258713472806921',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 9,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 30,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1070802,
#     'honorLevel': 6,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 132147,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 28,
#   'score': 71610,
#   'userId': '155635838042374144',
#   'userName': 'さん',
#   'userCard': {'level': 60,
#    'cardId': 710,
#    'masterRank': 3,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'へぇ。真田、タンポポ知ってるんだ',
#    'userId': '155635838042374144',
#    'twitterId': 'hian3g',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': []},
#  {'id': 132148,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 29,
#   'score': 69948,
#   'userId': '6068399742738443',
#   'userName': 'こしゅ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '幸せになれますように♧',
#    'userId': '6068399742738443',
#    'twitterId': 'kxsiiu',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 236,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132149,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 30,
#   'score': 64610,
#   'userId': '5227060444504074',
#   'userName': 'ひぐね♡',
#   'userCard': {'level': 60,
#    'cardId': 708,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'この夜をいっそ喰らってしまいたい',
#    'userId': '5227060444504074',
#    'twitterId': 'higu_wtc',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1071902,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1071903,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 75,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132150,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 31,
#   'score': 60610,
#   'userId': '5182336962523145',
#   'userName': 'よーこ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 4,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'しずあい\xa0──────────',
#    'userId': '5182336962523145',
#    'twitterId': 'Sasareta_',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1070802,
#     'honorLevel': 3,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 30,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132151,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 32,
#   'score': 57449,
#   'userId': '28612442070491150',
#   'userName': 'pig man',
#   'userCard': {'level': 60,
#    'cardId': 547,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '28612442070491150',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 981,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3013,
#     'honorLevel': 41,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132152,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 33,
#   'score': 57333,
#   'userId': '114148725944832005',
#   'userName': 'えね@イベラン？',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '114148725944832005',
#    'twitterId': 'GlycinAM429',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2719,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132153,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 34,
#   'score': 56560,
#   'userId': '5146473805500429',
#   'userName': 'L.F',
#   'userCard': {'level': 60,
#    'cardId': 922,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'よろしくお願いします。',
#    'userId': '5146473805500429',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 23,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132154,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 35,
#   'score': 55869,
#   'userId': '8535526684786692',
#   'userName': 'めりめりいちゃん',
#   'userCard': {'level': 60,
#    'cardId': 547,
#    'masterRank': 2,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '(\xa0;\xa0_\xa0;\xa0)/~~~',
#    'userId': '8535526684786692',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1735,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132155,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 36,
#   'score': 54040,
#   'userId': '119015630884990984',
#   'userName': 'サイゼのチョリソー',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'チアフルの時はエゴイスト探してます。MVがモチベ。',
#    'userId': '119015630884990984',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 145,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132156,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 37,
#   'score': 54005,
#   'userId': '447953849191706631',
#   'userName': '香茶',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '緩く楽しくやってます',
#    'userId': '447953849191706631',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2,
#     'honorLevel': 3,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132157,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 38,
#   'score': 52954,
#   'userId': '115628614812491778',
#   'userName': '( ﾟ∀ﾟ)o彡゜え',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '115628614812491778',
#    'twitterId': 'yut294',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1983,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3014,
#     'honorLevel': 43,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132166,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 47,
#   'score': 48020,
#   'userId': '5318112052371460',
#   'userName': 'i[Love]ly!',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '5318112052371460',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1122,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1428,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132158,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 39,
#   'score': 52026,
#   'userId': '61798409002029060',
#   'userName': 'ゐ',
#   'userCard': {'level': 60,
#    'cardId': 547,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ポロセカ部の名にかけて精一杯頑張ろう',
#    'userId': '61798409002029060',
#    'twitterId': 'enoughhh_pad',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1978,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2723,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132159,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 40,
#   'score': 51852,
#   'userId': '126175161985224704',
#   'userName': '山田',
#   'userCard': {'level': 60,
#    'cardId': 266,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '冷汗汁',
#    'userId': '126175161985224704',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3013,
#     'honorLevel': 30,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132160,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 41,
#   'score': 51842,
#   'userId': '5119897588187151',
#   'userName': 'しえすた',
#   'userCard': {'level': 60,
#    'cardId': 924,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ゆるゆるやってます♪',
#    'userId': '5119897588187151',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1977,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1050702,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1050703,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 132161,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 42,
#   'score': 51520,
#   'userId': '192159908313456654',
#   'userName': 'リツ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'たいよろ',
#    'userId': '192159908313456654',
#    'twitterId': 'Ritsu0039',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1070802,
#     'honorLevel': 7,
#     'bondsHonorWordId': 1070803,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 2721,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3342,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132162,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 43,
#   'score': 50646,
#   'userId': '8159558409244685',
#   'userName': 'モモジャン大好きおぢ',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'Jumpin！ありがとう',
#    'userId': '8159558409244685',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1050601,
#     'honorLevel': 5,
#     'bondsHonorWordId': 1050601,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 1070802,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1070801,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 132163,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 44,
#   'score': 48829,
#   'userId': '5119893595365387',
#   'userName': 'frownie',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'game\xa0hard',
#    'userId': '5119893595365387',
#    'twitterId': 'frownieman',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 236,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132164,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 45,
#   'score': 48807,
#   'userId': '5142905434259456',
#   'userName': 'リナ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 1,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '世界一のアイドル',
#    'userId': '5142905434259456',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1979,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1050702,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1050702,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'}]},
#  {'id': 132165,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 46,
#   'score': 48369,
#   'userId': '142692024231419905',
#   'userName': '餞に赤薔薇を',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '招待◯\xa0イラストも専用mvもよかった',
#    'userId': '142692024231419905',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3550,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3035,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3346,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132167,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 48,
#   'score': 47845,
#   'userId': '211079248508788748',
#   'userName': '××',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '211079248508788748',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 82,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 1072101,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1072101,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal_unit_virtual_singer'}]},
#  {'id': 132168,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 49,
#   'score': 47541,
#   'userId': '51293891236061198',
#   'userName': 'ねころり',
#   'userCard': {'level': 60,
#    'cardId': 922,
#    'masterRank': 3,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'セカライ最高でした！！！！！',
#    'userId': '51293891236061198',
#    'twitterId': 'necololi',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1070802,
#     'honorLevel': 8,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 30,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132169,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 50,
#   'score': 47127,
#   'userId': '5154144252108811',
#   'userName': 'ジャガイモン',
#   'userCard': {'level': 60,
#    'cardId': 429,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'potatoになっている',
#    'userId': '5154144252108811',
#    'twitterId': 'maki_jyaga_riko',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 79,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 71,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 27,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132170,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 51,
#   'score': 47081,
#   'userId': '38458394012622854',
#   'userName': 'もあもあ笑顔♥',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '希望の花束届けます!',
#    'userId': '38458394012622854',
#    'twitterId': '87salmon',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 19,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1131602,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1131602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 3,
#     'honorId': 1050602,
#     'honorLevel': 2,
#     'bondsHonorWordId': 1050602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'}]},
#  {'id': 132171,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 52,
#   'score': 46874,
#   'userId': '39399136981741573',
#   'userName': 'パパイヤだよ〜',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'パパイヤだよ〜',
#    'userId': '39399136981741573',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 128,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132172,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 53,
#   'score': 46760,
#   'userId': '183376293274750982',
#   'userName': 'わさび豆腐',
#   'userCard': {'level': 60,
#    'cardId': 921,
#    'masterRank': 1,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '183376293274750982',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 74,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2165,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2166,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132173,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 54,
#   'score': 45990,
#   'userId': '5151515292119044',
#   'userName': 'ぽめ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'このセカイが変わる\xa0唯一の魔法',
#    'userId': '5151515292119044',
#    'twitterId': 'prsk_pome',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 27,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1070802,
#     'honorLevel': 3,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 3,
#     'honorId': 1978,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132174,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 55,
#   'score': 45815,
#   'userId': '153273353750446091',
#   'userName': '愛莉大好き！',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 5,
# ...
#   'score': 37555,
#   'userId': '366741726210154502',
#   'userName': 'sumi',
#   'userCard': {'level': 60,
#    'cardId': 190,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'てんつか、',
#    'userId': '366741726210154502',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1071401,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1071401,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 25,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 54,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132204,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 85,
#   'score': 37275,
#   'userId': '87804761977597957',
#   'userName': 'にっちー',
#   'userCard': {'level': 60,
#    'cardId': 243,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '87804761977597957',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1070802,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1070802,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132205,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 86,
#   'score': 36995,
#   'userId': '109268702276489223',
#   'userName': 'ぴあ\u3000',
#   'userCard': {'level': 60,
#    'cardId': 547,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'フリック忘れがち',
#    'userId': '109268702276489223',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 2905,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 532,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132206,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 87,
#   'score': 36785,
#   'userId': '102693844759420928',
#   'userName': 'あんこもち',
#   'userCard': {'level': 60,
#    'cardId': 266,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'エキスパート25レベ全曲フルコン頑張ります!イベランも!',
#    'userId': '102693844759420928',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 70,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 54,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3012,
#     'honorLevel': 29,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132207,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 88,
#   'score': 36715,
#   'userId': '316160720722046981',
#   'userName': 'Ru_な*ライボ返',
#   'userCard': {'level': 60,
#    'cardId': 160,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'ガチャどうしよう…(\xa0；∀；)',
#    'userId': '316160720722046981',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1131602,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1131602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 50,
#     'honorLevel': 4,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 62,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132208,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 89,
#   'score': 36575,
#   'userId': '197625088187129864',
#   'userName': 'まさ',
#   'userCard': {'level': 60,
#    'cardId': 125,
#    'masterRank': 0,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'バレンタインガチャ160連して星4\xa04枚\xa0遥だけ出なかった\xa0',
#    'userId': '197625088187129864',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1050602,
#     'honorLevel': 3,
#     'bondsHonorWordId': 1050602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 22,
#     'honorLevel': 10,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 2317,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132209,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 90,
#   'score': 36365,
#   'userId': '364656555189993474',
#   'userName': 'yuki☆',
#   'userCard': {'level': 60,
#    'cardId': 402,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '3月からクリスタルが1桁無くなった',
#    'userId': '364656555189993474',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 38,
#     'honorLevel': 6,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 14,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 357,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132210,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 91,
#   'score': 36202,
#   'userId': '6061198927831048',
#   'userName': '愛莉のパフェ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '6061198927831048',
#    'twitterId': 'kuro11kiri1',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3134,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 3013,
#     'honorLevel': 19,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3229,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132211,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 92,
#   'score': 36156,
#   'userId': '5180516224225290',
#   'userName': 'せ',
#   'userCard': {'level': 60,
#    'cardId': 671,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '5180516224225290',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1111202,
#     'honorLevel': 10,
#     'bondsHonorWordId': 1111201,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 3709,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3691,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132212,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 93,
#   'score': 35875,
#   'userId': '152015732284108808',
#   'userName': 'ムシャコラ',
#   'userCard': {'level': 60,
#    'cardId': 923,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '天井か...',
#    'userId': '152015732284108808',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1050602,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1050602,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 25,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3012,
#     'honorLevel': 42,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132213,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 94,
#   'score': 35840,
#   'userId': '10648382587105289',
#   'userName': '下院',
#   'userCard': {'level': 60,
#    'cardId': 803,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '10648382587105289',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 116,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 26,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 78,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132214,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 95,
#   'score': 35700,
#   'userId': '29161838533201930',
#   'userName': '※かりんと',
#   'userCard': {'level': 60,
#    'cardId': 424,
#    'masterRank': 0,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'よろしくお願いします！',
#    'userId': '29161838533201930',
#    'twitterId': '_ka_po_8_',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 22,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 211,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 3349,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132215,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 96,
#   'score': 35490,
#   'userId': '240791763094941709',
#   'userName': '快晴\u3000＠ラグい',
#   'userCard': {'level': 60,
#    'cardId': 350,
#    'masterRank': 5,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'イフ遥様復刻、遥様バナー、モモジャンワールドリンク.....',
#    'userId': '240791763094941709',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 22,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 1060702,
#     'honorLevel': 1,
#     'bondsHonorWordId': 1060701,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 3,
#     'honorId': 3884,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132216,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 97,
#   'score': 35420,
#   'userId': '254229631640580106',
#   'userName': '糸愛',
#   'userCard': {'level': 60,
#    'cardId': 190,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '',
#    'userId': '254229631640580106',
#    'twitterId': '',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1050702,
#     'honorLevel': 4,
#     'bondsHonorWordId': 1050703,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'normal'},
#    {'seq': 2,
#     'honorId': 18,
#     'honorLevel': 7,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 26,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132217,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 98,
#   'score': 35420,
#   'userId': '5134857626058761',
#   'userName': 'まったり勢',
#   'userCard': {'level': 60,
#    'cardId': 840,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': 'リズム隊アナザーボーカルお願い……',
#    'userId': '5134857626058761',
#    'twitterId': 'tanya89319',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 1030402,
#     'honorLevel': 3,
#     'bondsHonorWordId': 1030402,
#     'profileHonorType': 'bonds',
#     'bondsHonorViewType': 'reverse'},
#    {'seq': 2,
#     'honorId': 15,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 10,
#     'honorLevel': 8,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132218,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 99,
#   'score': 35420,
#   'userId': '6230366143365128',
#   'userName': 'カラパス大概にSay',
#   'userCard': {'level': 60,
#    'cardId': 671,
#    'masterRank': 5,
#    'defaultImage': 'original',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '無料単発☆4なし132日目',
#    'userId': '6230366143365128',
#    'twitterId': ' ',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 3274,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 735,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 3,
#     'honorId': 928,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'}]},
#  {'id': 132219,
#   'eventId': 130,
#   'timestamp': '2024-05-09T11:03:00.274Z',
#   'rank': 100,
#   'score': 35282,
#   'userId': '5146234616950798',
#   'userName': 'しろまる',
#   'userCard': {'level': 60,
#    'cardId': 840,
#    'masterRank': 2,
#    'defaultImage': 'special_training',
#    'specialTrainingStatus': 'done'},
#   'userProfile': {'word': '咲希ちゃんのツインテぽよぽよ〜',
#    'userId': '5146234616950798',
#    'twitterId': 'siromaru_game',
#    'profileImageType': 'leader'},
#   'userCheerfulCarnival': {},
#   'userProfileHonors': [{'seq': 1,
#     'honorId': 83,
#     'honorLevel': 2,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal',
#     'bondsHonorViewType': 'none'},
#    {'seq': 2,
#     'honorId': 115,
#     'honorLevel': 5,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal'},
#    {'seq': 3,
#     'honorId': 112,
#     'honorLevel': 1,
#     'bondsHonorWordId': 0,
#     'profileHonorType': 'normal'}]}]

# %% [markdown]
# ---
# ### Google spread sheet への書き込みを考える

# %%
import gspread
from google.oauth2.service_account import Credentials
from gspread.utils import rowcol_to_a1
SCOPES = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive",
]
creds = Credentials.from_service_account_file("./keys/rock-perception-419201-eb5dbe72985b.json", scopes=SCOPES)
gc = gspread.authorize(creds)
SPREADSHEET_ID = "1ySZ0ja5_K1ak6mFCL3n-N_-mS_KDMsmFv8TeEm2TQCo"
SHEET_NAME = "Config"

# %%
sh = gc.open_by_key(SPREADSHEET_ID)
ws = sh.worksheet(SHEET_NAME)

# %%
values = ws.get("A1:C10")
print("READ:", values)
# Out:
# READ: [['EventName'], ['ChapterNo'], ['Runners']]

# %%
def read_config_values(spreadsheet_id: str,
                       sheet_name: str = "Config") -> dict:
    ws = gc.open_by_key(spreadsheet_id).worksheet(sheet_name)
    event_name = (ws.acell("B1").value or "").strip()
    raw_chapter = (ws.acell("B2").value or "").strip()
    chapter_no = None
    if raw_chapter:
        try:
            chapter_no = int(raw_chapter)
        except ValueError:
            try:
                chapter_no = int(float(raw_chapter))
            except Exception:
                chapter_no = None
                
    row3 = ws.row_values(3)
    runners = [v.strip() for v in row3[1:] if isinstance(v, str) and v.strip()]
    return {
        "EventName": event_name,
        "ChapterNo": chapter_no,
        "Runners": runners,
    }

# %%
config = read_config_values(SPREADSHEET_ID)

# %%
config.get("EventName")
# Out:
# 'All ways Jump! with you'

# %%
get_event_info_by_name(config.get("EventName"))
# Out:
# {'id': 176,
#  'eventType': 'world_bloom',
#  'name': 'All ways Jump! with you',
#  'assetbundleName': 'event_wl_2nd_idol_2025',
#  'bgmAssetbundleName': 'event/event_wl_2nd_idol_2025/bgm/event_wl_2nd_idol_2025_top',
#  'eventPointAssetbundleName': 'icon_point',
#  'eventOnlyComponentDisplayStartAt': 1754622000000,
#  'startAt': 1754650800000,
#  'aggregateAt': 1755687599000,
#  'rankingAnnounceAt': 1755688199000,
#  'distributionStartAt': 1755741599000,
#  'eventOnlyComponentDisplayEndAt': 1755831599000,
#  'closedAt': 1755842399000,
#  'distributionEndAt': 1756997999000,
#  'virtualLiveId': 393,
#  'unit': 'idol',
#  'eventRankingRewardRanges': [{'id': 5309,
#    'eventId': 176,
#    'fromRank': 1,
#    'toRank': 1,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5309,
#      'eventRankingRewardRangeId': 5309,
#      'resourceBoxId': 5309}]},
#   {'id': 5310,
#    'eventId': 176,
#    'fromRank': 2,
#    'toRank': 2,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5310,
#      'eventRankingRewardRangeId': 5310,
#      'resourceBoxId': 5310}]},
#   {'id': 5311,
#    'eventId': 176,
#    'fromRank': 3,
#    'toRank': 3,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5311,
#      'eventRankingRewardRangeId': 5311,
#      'resourceBoxId': 5311}]},
#   {'id': 5312,
#    'eventId': 176,
#    'fromRank': 4,
#    'toRank': 4,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5312,
#      'eventRankingRewardRangeId': 5312,
#      'resourceBoxId': 5312}]},
#   {'id': 5313,
#    'eventId': 176,
#    'fromRank': 5,
#    'toRank': 5,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5313,
#      'eventRankingRewardRangeId': 5313,
#      'resourceBoxId': 5313}]},
#   {'id': 5314,
#    'eventId': 176,
#    'fromRank': 6,
#    'toRank': 6,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5314,
#      'eventRankingRewardRangeId': 5314,
#      'resourceBoxId': 5314}]},
#   {'id': 5315,
#    'eventId': 176,
#    'fromRank': 7,
#    'toRank': 7,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5315,
#      'eventRankingRewardRangeId': 5315,
#      'resourceBoxId': 5315}]},
#   {'id': 5316,
#    'eventId': 176,
#    'fromRank': 8,
#    'toRank': 8,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5316,
#      'eventRankingRewardRangeId': 5316,
#      'resourceBoxId': 5316}]},
#   {'id': 5317,
#    'eventId': 176,
#    'fromRank': 9,
#    'toRank': 9,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5317,
#      'eventRankingRewardRangeId': 5317,
#      'resourceBoxId': 5317}]},
#   {'id': 5318,
#    'eventId': 176,
#    'fromRank': 10,
#    'toRank': 10,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5318,
#      'eventRankingRewardRangeId': 5318,
#      'resourceBoxId': 5318}]},
#   {'id': 5319,
#    'eventId': 176,
#    'fromRank': 11,
#    'toRank': 20,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5319,
#      'eventRankingRewardRangeId': 5319,
#      'resourceBoxId': 5319}]},
#   {'id': 5320,
#    'eventId': 176,
#    'fromRank': 21,
#    'toRank': 30,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5320,
#      'eventRankingRewardRangeId': 5320,
#      'resourceBoxId': 5320}]},
#   {'id': 5321,
#    'eventId': 176,
#    'fromRank': 31,
#    'toRank': 40,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5321,
#      'eventRankingRewardRangeId': 5321,
#      'resourceBoxId': 5321}]},
#   {'id': 5322,
#    'eventId': 176,
#    'fromRank': 41,
#    'toRank': 50,
#    'isToRankBorder': False,
#    'eventRankingRewards': [{'id': 5322,
#      'eventRankingRewardRangeId': 5322,
#      'resourceBoxId': 5322}]},
#   {'id': 5323,
#    'eventId': 176,
#    'fromRank': 51,
#    'toRank': 100,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5323,
#      'eventRankingRewardRangeId': 5323,
#      'resourceBoxId': 5323}]},
#   {'id': 5324,
#    'eventId': 176,
#    'fromRank': 101,
#    'toRank': 200,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5324,
#      'eventRankingRewardRangeId': 5324,
#      'resourceBoxId': 5324}]},
#   {'id': 5325,
#    'eventId': 176,
#    'fromRank': 201,
#    'toRank': 300,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5325,
#      'eventRankingRewardRangeId': 5325,
#      'resourceBoxId': 5325}]},
#   {'id': 5326,
#    'eventId': 176,
#    'fromRank': 301,
#    'toRank': 400,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5326,
#      'eventRankingRewardRangeId': 5326,
#      'resourceBoxId': 5326}]},
#   {'id': 5327,
#    'eventId': 176,
#    'fromRank': 401,
#    'toRank': 500,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5327,
#      'eventRankingRewardRangeId': 5327,
#      'resourceBoxId': 5327}]},
#   {'id': 5328,
#    'eventId': 176,
#    'fromRank': 501,
#    'toRank': 1000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5328,
#      'eventRankingRewardRangeId': 5328,
#      'resourceBoxId': 5328}]},
#   {'id': 5329,
#    'eventId': 176,
#    'fromRank': 1001,
#    'toRank': 1500,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5329,
#      'eventRankingRewardRangeId': 5329,
#      'resourceBoxId': 5329}]},
#   {'id': 5330,
#    'eventId': 176,
#    'fromRank': 1501,
#    'toRank': 2000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5330,
#      'eventRankingRewardRangeId': 5330,
#      'resourceBoxId': 5330}]},
#   {'id': 5331,
#    'eventId': 176,
#    'fromRank': 2001,
#    'toRank': 2500,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5331,
#      'eventRankingRewardRangeId': 5331,
#      'resourceBoxId': 5331}]},
#   {'id': 5332,
#    'eventId': 176,
#    'fromRank': 2501,
#    'toRank': 3000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5332,
#      'eventRankingRewardRangeId': 5332,
#      'resourceBoxId': 5332}]},
#   {'id': 5333,
#    'eventId': 176,
#    'fromRank': 3001,
#    'toRank': 4000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5333,
#      'eventRankingRewardRangeId': 5333,
#      'resourceBoxId': 5333}]},
#   {'id': 5334,
#    'eventId': 176,
#    'fromRank': 4001,
#    'toRank': 5000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5334,
#      'eventRankingRewardRangeId': 5334,
#      'resourceBoxId': 5334}]},
#   {'id': 5335,
#    'eventId': 176,
#    'fromRank': 5001,
#    'toRank': 10000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5335,
#      'eventRankingRewardRangeId': 5335,
#      'resourceBoxId': 5335}]},
#   {'id': 5336,
#    'eventId': 176,
#    'fromRank': 10001,
#    'toRank': 20000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5336,
#      'eventRankingRewardRangeId': 5336,
#      'resourceBoxId': 5336}]},
#   {'id': 5337,
#    'eventId': 176,
#    'fromRank': 20001,
#    'toRank': 30000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5337,
#      'eventRankingRewardRangeId': 5337,
#      'resourceBoxId': 5337}]},
#   {'id': 5338,
#    'eventId': 176,
#    'fromRank': 30001,
#    'toRank': 40000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5338,
#      'eventRankingRewardRangeId': 5338,
#      'resourceBoxId': 5338}]},
#   {'id': 5339,
#    'eventId': 176,
#    'fromRank': 40001,
#    'toRank': 50000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5339,
#      'eventRankingRewardRangeId': 5339,
#      'resourceBoxId': 5339}]},
#   {'id': 5340,
#    'eventId': 176,
#    'fromRank': 50001,
#    'toRank': 100000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5340,
#      'eventRankingRewardRangeId': 5340,
#      'resourceBoxId': 5340}]},
#   {'id': 5341,
#    'eventId': 176,
#    'fromRank': 100001,
#    'toRank': 200000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5341,
#      'eventRankingRewardRangeId': 5341,
#      'resourceBoxId': 5341}]},
#   {'id': 5342,
#    'eventId': 176,
#    'fromRank': 200001,
#    'toRank': 300000,
#    'isToRankBorder': True,
#    'eventRankingRewards': [{'id': 5342,
#      'eventRankingRewardRangeId': 5342,
#      'resourceBoxId': 5342}]}]}

# %%
event_id, start, end = filter_event_info(get_event_info_by_name(config.get("EventName")))

# %%
event_id
# Out:
# 176

# %%
start
# Out:
# datetime.datetime(2025, 8, 8, 20, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400)))

# %%
end
# Out:
# datetime.datetime(2025, 8, 20, 19, 59, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400)))

# %%
def format_shift_table(
    spreadsheet_id: str,
    start: datetime,
    end: datetime,
    sheet_title: str = "Shift",
    service_account_json: str = "service_account.json",
) -> str:
    if start > end:
        raise ValueError("start must be <= end")
    sh = gc.open_by_key(spreadsheet_id)
    start_h = start.replace(minute=0, second=0, microsecond=0)
    end_h   = end.replace(minute=0, second=0, microsecond=0)

    days = []
    d = start.date()
    end_d = end.date()
    while d <= end_d:
        days.append(d)
        d += timedelta(days=1)

    total_rows = 25
    total_cols = (1 + (len(days) - 1) * 5 + 4) if days else 5
    try:
        ws = sh.add_worksheet(title=sheet_title, rows=total_rows, cols=total_cols)
    except gspread.exceptions.APIError:
        ws = sh.add_worksheet(
            title=f"{sheet_title}_{int(datetime.now().timestamp())}",
            rows=total_rows,
            cols=total_cols,
        )

    for i, day in enumerate(days):
        col = 1 + i * 5  # A=1, F=6, K=11 ...
        if day == start_h.date():
            day_start_hour = start_h.hour
        else:
            day_start_hour = 0
        if day == end_h.date():
            day_end_hour = end_h.hour
        else:
            day_end_hour = 23

        hours_col = []
        for h in range(24):
            hours_col.append([f"{h:02d}:00"] if day_start_hour <= h <= day_end_hour else [""])

        values = [[day.strftime("%Y-%m-%d")]] + hours_col  # 25x1
        cell_range = f"{rowcol_to_a1(1, col)}:{rowcol_to_a1(25, col)}"
        full_range = f"{ws.title}!{cell_range}"
        sh.values_update(
            full_range,
            params={"valueInputOption": "USER_ENTERED"},
            body={"values": values},
        )

    try:
        ws.freeze(rows=1)
    except Exception:
        pass

    return ws.title

# %%
created_title = format_shift_table(SPREADSHEET_ID, start, end)
